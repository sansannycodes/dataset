# %%
import pandas as pd
data = pd.read_csv("C:\\Users\\SANATH\\Downloads\\Diabetes Missing Data.csv")
print(data)
# Out:
#      Pregnant  Glucose  Diastolic_BP  Skin_Fold  Serum_Insulin   BMI  \
# 0           6    148.0          72.0       35.0            NaN  33.6
# 1           1     85.0          66.0       29.0            NaN  26.6
# 2           8    183.0          64.0        NaN            NaN  23.3
# 3           1     89.0          66.0       23.0           94.0  28.1
# 4           0    137.0          40.0       35.0          168.0  43.1
# ..        ...      ...           ...        ...            ...   ...
# 763        10    101.0          76.0       48.0          180.0  32.9
# 764         2    122.0          70.0       27.0            NaN  36.8
# 765         5    121.0          72.0       23.0          112.0  26.2
# 766         1    126.0          60.0        NaN            NaN  30.1
# 767         1     93.0          70.0       31.0            NaN  30.4
#
#      Diabetes_Pedigree  Age  Class
# 0                0.627   50      1
# 1                0.351   31      0
# ...

# %%
null_counts = data.isnull().sum
print(null_counts)
# Out:
# <bound method DataFrame.sum of      Pregnant  Glucose  Diastolic_BP  Skin_Fold  Serum_Insulin    BMI  \
# 0       False    False         False      False           True  False
# 1       False    False         False      False           True  False
# 2       False    False         False       True           True  False
# 3       False    False         False      False          False  False
# 4       False    False         False      False          False  False
# ..        ...      ...           ...        ...            ...    ...
# 763     False    False         False      False          False  False
# 764     False    False         False      False           True  False
# 765     False    False         False      False          False  False
# 766     False    False         False       True           True  False
# 767     False    False         False      False           True  False
#
#      Diabetes_Pedigree    Age  Class
# 0                False  False  False
# ...

# %%
data.dropna
# Out:
# <bound method DataFrame.dropna of      Pregnant  Glucose  Diastolic_BP  Skin_Fold  Serum_Insulin   BMI  \
# 0           6    148.0          72.0       35.0            NaN  33.6
# 1           1     85.0          66.0       29.0            NaN  26.6
# 2           8    183.0          64.0        NaN            NaN  23.3
# 3           1     89.0          66.0       23.0           94.0  28.1
# 4           0    137.0          40.0       35.0          168.0  43.1
# ..        ...      ...           ...        ...            ...   ...
# 763        10    101.0          76.0       48.0          180.0  32.9
# 764         2    122.0          70.0       27.0            NaN  36.8
# 765         5    121.0          72.0       23.0          112.0  26.2
# 766         1    126.0          60.0        NaN            NaN  30.1
# 767         1     93.0          70.0       31.0            NaN  30.4
#
#      Diabetes_Pedigree  Age  Class
# 0                0.627   50      1
# ...

# %%
data.isnull()
# Out:
#      Pregnant  Glucose  Diastolic_BP  Skin_Fold  Serum_Insulin    BMI  \
# 0       False    False         False      False           True  False
# 1       False    False         False      False           True  False
# 2       False    False         False       True           True  False
# 3       False    False         False      False          False  False
# 4       False    False         False      False          False  False
# ..        ...      ...           ...        ...            ...    ...
# 763     False    False         False      False          False  False
# 764     False    False         False      False           True  False
# 765     False    False         False      False          False  False
# 766     False    False         False       True           True  False
# 767     False    False         False      False           True  False
#
#      Diabetes_Pedigree    Age  Class
# 0                False  False  False
# 1                False  False  False
# ...

# %%
data.notnull()
# Out:
#      Pregnant  Glucose  Diastolic_BP  Skin_Fold  Serum_Insulin   BMI  \
# 0        True     True          True       True          False  True
# 1        True     True          True       True          False  True
# 2        True     True          True      False          False  True
# 3        True     True          True       True           True  True
# 4        True     True          True       True           True  True
# ..        ...      ...           ...        ...            ...   ...
# 763      True     True          True       True           True  True
# 764      True     True          True       True          False  True
# 765      True     True          True       True           True  True
# 766      True     True          True      False          False  True
# 767      True     True          True       True          False  True
#
#      Diabetes_Pedigree   Age  Class
# 0                 True  True   True
# 1                 True  True   True
# ...

# %%
data.fillna
# Out:
# <bound method NDFrame.fillna of      Pregnant  Glucose  Diastolic_BP  Skin_Fold  Serum_Insulin   BMI  \
# 0           6    148.0          72.0       35.0            NaN  33.6
# 1           1     85.0          66.0       29.0            NaN  26.6
# 2           8    183.0          64.0        NaN            NaN  23.3
# 3           1     89.0          66.0       23.0           94.0  28.1
# 4           0    137.0          40.0       35.0          168.0  43.1
# ..        ...      ...           ...        ...            ...   ...
# 763        10    101.0          76.0       48.0          180.0  32.9
# 764         2    122.0          70.0       27.0            NaN  36.8
# 765         5    121.0          72.0       23.0          112.0  26.2
# 766         1    126.0          60.0        NaN            NaN  30.1
# 767         1     93.0          70.0       31.0            NaN  30.4
#
#      Diabetes_Pedigree  Age  Class
# 0                0.627   50      1
# 1                0.351   31      0
# ...

# %%
data.replace()
# Out:
# C:\Users\SANATH\AppData\Local\Temp\ipykernel_11420\295544180.py:1: FutureWarning: DataFrame.replace without 'value' and with non-dict-like 'to_replace' is deprecated and will raise in a future version. Explicitly specify the new values instead.
#   data.replace()
#      Pregnant  Glucose  Diastolic_BP  Skin_Fold  Serum_Insulin   BMI  \
# 0           6    148.0          72.0       35.0            NaN  33.6
# 1           1     85.0          66.0       29.0            NaN  26.6
# 2           8    183.0          64.0       29.0            NaN  23.3
# 3           1     89.0          66.0       23.0           94.0  28.1
# 4           0    137.0          40.0       35.0          168.0  43.1
# ..        ...      ...           ...        ...            ...   ...
# 763        10    101.0          76.0       48.0          180.0  32.9
# 764         2    122.0          70.0       27.0          180.0  36.8
# 765         5    121.0          72.0       23.0          112.0  26.2
# ...

# %%
-data.interpolate()
# Out:
#      Pregnant  Glucose  Diastolic_BP  Skin_Fold  Serum_Insulin   BMI  \
# 0          -6   -148.0         -72.0      -35.0            NaN -33.6
# 1          -1    -85.0         -66.0      -29.0            NaN -26.6
# 2          -8   -183.0         -64.0      -26.0            NaN -23.3
# 3          -1    -89.0         -66.0      -23.0          -94.0 -28.1
# 4           0   -137.0         -40.0      -35.0         -168.0 -43.1
# ..        ...      ...           ...        ...            ...   ...
# 763       -10   -101.0         -76.0      -48.0         -180.0 -32.9
# 764        -2   -122.0         -70.0      -27.0         -146.0 -36.8
# 765        -5   -121.0         -72.0      -23.0         -112.0 -26.2
# 766        -1   -126.0         -60.0      -27.0         -112.0 -30.1
# 767        -1    -93.0         -70.0      -31.0         -112.0 -30.4
#
#      Diabetes_Pedigree  Age  Class
# 0               -0.627  -50     -1
# 1               -0.351  -31      0
# ...

# %%
data.isnull().sum()
# Out:
# Pregnant               0
# Glucose                5
# Diastolic_BP          35
# Skin_Fold            227
# Serum_Insulin        374
# BMI                   11
# Diabetes_Pedigree      0
# Age                    0
# Class                  0
# dtype: int64

# %%
data.head(10).isnull()
# Out:
#    Pregnant  Glucose  Diastolic_BP  Skin_Fold  Serum_Insulin    BMI  \
# 0     False    False         False      False           True  False
# 1     False    False         False      False           True  False
# 2     False    False         False       True           True  False
# 3     False    False         False      False          False  False
# 4     False    False         False      False          False  False
# 5     False    False         False       True           True  False
# 6     False    False         False      False          False  False
# 7     False    False          True       True           True  False
# 8     False    False         False      False          False  False
# 9     False    False         False       True           True   True
#
#    Diabetes_Pedigree    Age  Class
# 0              False  False  False
# 1              False  False  False
# 2              False  False  False
# 3              False  False  False
# 4              False  False  False
# ...

# %%
data.tail(5).isnull()
# Out:
#      Pregnant  Glucose  Diastolic_BP  Skin_Fold  Serum_Insulin    BMI  \
# 763     False    False         False      False          False  False
# 764     False    False         False      False           True  False
# 765     False    False         False      False          False  False
# 766     False    False         False       True           True  False
# 767     False    False         False      False           True  False
#
#      Diabetes_Pedigree    Age  Class
# 763              False  False  False
# 764              False  False  False
# 765              False  False  False
# 766              False  False  False
# 767              False  False  False

# %%
data.backfill
# Out:
# <bound method NDFrame.backfill of      Pregnant  Glucose  Diastolic_BP  Skin_Fold  Serum_Insulin   BMI  \
# 0           6    148.0          72.0       35.0            NaN  33.6
# 1           1     85.0          66.0       29.0            NaN  26.6
# 2           8    183.0          64.0        NaN            NaN  23.3
# 3           1     89.0          66.0       23.0           94.0  28.1
# 4           0    137.0          40.0       35.0          168.0  43.1
# ..        ...      ...           ...        ...            ...   ...
# 763        10    101.0          76.0       48.0          180.0  32.9
# 764         2    122.0          70.0       27.0            NaN  36.8
# 765         5    121.0          72.0       23.0          112.0  26.2
# 766         1    126.0          60.0        NaN            NaN  30.1
# 767         1     93.0          70.0       31.0            NaN  30.4
#
#      Diabetes_Pedigree  Age  Class
# 0                0.627   50      1
# ...

# %%
data.ffill
# Out:
# <bound method NDFrame.ffill of      Pregnant  Glucose  Diastolic_BP  Skin_Fold  Serum_Insulin   BMI  \
# 0           6    148.0          72.0       35.0            NaN  33.6
# 1           1     85.0          66.0       29.0            NaN  26.6
# 2           8    183.0          64.0        NaN            NaN  23.3
# 3           1     89.0          66.0       23.0           94.0  28.1
# 4           0    137.0          40.0       35.0          168.0  43.1
# ..        ...      ...           ...        ...            ...   ...
# 763        10    101.0          76.0       48.0          180.0  32.9
# 764         2    122.0          70.0       27.0            NaN  36.8
# 765         5    121.0          72.0       23.0          112.0  26.2
# 766         1    126.0          60.0        NaN            NaN  30.1
# 767         1     93.0          70.0       31.0            NaN  30.4
#
#      Diabetes_Pedigree  Age  Class
# 0                0.627   50      1
# 1                0.351   31      0
# ...

# %%
data.pad
# Out:
# <bound method NDFrame.pad of      Pregnant  Glucose  Diastolic_BP  Skin_Fold  Serum_Insulin   BMI  \
# 0           6    148.0          72.0       35.0            NaN  33.6
# 1           1     85.0          66.0       29.0            NaN  26.6
# 2           8    183.0          64.0        NaN            NaN  23.3
# 3           1     89.0          66.0       23.0           94.0  28.1
# 4           0    137.0          40.0       35.0          168.0  43.1
# ..        ...      ...           ...        ...            ...   ...
# 763        10    101.0          76.0       48.0          180.0  32.9
# 764         2    122.0          70.0       27.0            NaN  36.8
# 765         5    121.0          72.0       23.0          112.0  26.2
# 766         1    126.0          60.0        NaN            NaN  30.1
# 767         1     93.0          70.0       31.0            NaN  30.4
#
#      Diabetes_Pedigree  Age  Class
# 0                0.627   50      1
# 1                0.351   31      0
# ...
